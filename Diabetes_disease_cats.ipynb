# %%
import IPython
import pandas as pd
import numpy as np
from statistics import mode
import matplotlib.pyplot as plt

# %%
df_ori = pd.read_csv("diabetic_data.csv")
df_ori.head().T
# Out:
#                                                  0          1  \
# encounter_id                               2278392     149190
# patient_nbr                                8222157   55629189
# race                                     Caucasian  Caucasian
# gender                                      Female     Female
# age                                         [0-10)    [10-20)
# weight                                           ?          ?
# admission_type_id                                6          1
# discharge_disposition_id                        25          1
# admission_source_id                              1          7
# time_in_hospital                                 1          3
# payer_code                                       ?          ?
# medical_specialty         Pediatrics-Endocrinology          ?
# num_lab_procedures                              41         59
# num_procedures                                   0          0
# ...

# %%
# Selecting rows based on partial NOT present in the field
df_ori[~df_ori['diag_1'].str.contains("250") & ~df_ori['diag_2'].str.contains("250") &
       ~df_ori['diag_3'].str.contains("250")][['diag_1','diag_2','diag_3','number_diagnoses']].head()

# Selecting rows based on partial string
df_ori[df_ori['diag_1'].str.contains("250")].head()
# Out:
#     encounter_id  patient_nbr             race  gender      age weight  \
# 0        2278392      8222157        Caucasian  Female   [0-10)      ?
# 10         28236     89869032  AfricanAmerican  Female  [40-50)      ?
# 52        590346     37746639  AfricanAmerican  Female  [40-50)      ?
# 56        630342     93232917  AfricanAmerican  Female  [50-60)      ?
# 60        676422     63754317  AfricanAmerican  Female  [70-80)      ?
#
#     admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                   6                        25                    1
# 10                  1                         1                    7
# 52                  1                         6                    7
# 56                  3                         6                    2
# 60                  1                         1                    7
#
#     time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# ...
