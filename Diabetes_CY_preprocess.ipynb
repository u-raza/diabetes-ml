# %%
import IPython
import pandas as pd
import numpy as np
from statistics import mode
import matplotlib.pyplot as plt

# %%
df_ori = pd.read_csv("diabetic_data.csv")
df_ori.shape
# Out:
# (101766, 50)

# %%
print('--Examine the data type--')
print(df_ori.info())
df_ori.describe()
# Out:
# --Examine the data type--
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
# encounter_id                101766 non-null int64
# patient_nbr                 101766 non-null int64
# race                        101766 non-null object
# gender                      101766 non-null object
# age                         101766 non-null object
# weight                      101766 non-null object
# admission_type_id           101766 non-null int64
# discharge_disposition_id    101766 non-null int64
# admission_source_id         101766 non-null int64
# time_in_hospital            101766 non-null int64
# payer_code                  101766 non-null object
# medical_specialty           101766 non-null object
# num_lab_procedures          101766 non-null int64
# num_procedures              101766 non-null int64
# num_medications             101766 non-null int64
# number_outpatient           101766 non-null int64
# number_emergency            101766 non-null int64
# number_inpatient            101766 non-null int64
# diag_1                      101766 non-null object
# diag_2                      101766 non-null object
# diag_3                      101766 non-null object
# number_diagnoses            101766 non-null int64
# max_glu_serum               101766 non-null object
# A1Cresult                   101766 non-null object
# metformin                   101766 non-null object
# repaglinide                 101766 non-null object
# nateglinide                 101766 non-null object
# chlorpropamide              101766 non-null object
# glimepiride                 101766 non-null object
# acetohexamide               101766 non-null object
# glipizide                   101766 non-null object
# glyburide                   101766 non-null object
# tolbutamide                 101766 non-null object
# pioglitazone                101766 non-null object
# rosiglitazone               101766 non-null object
# acarbose                    101766 non-null object
# miglitol                    101766 non-null object
# troglitazone                101766 non-null object
# tolazamide                  101766 non-null object
# examide                     101766 non-null object
# citoglipton                 101766 non-null object
# insulin                     101766 non-null object
# glyburide-metformin         101766 non-null object
# glipizide-metformin         101766 non-null object
# glimepiride-pioglitazone    101766 non-null object
# metformin-rosiglitazone     101766 non-null object
# metformin-pioglitazone      101766 non-null object
# change                      101766 non-null object
# diabetesMed                 101766 non-null object
# readmitted                  101766 non-null object
# dtypes: int64(13), object(37)
# memory usage: 38.8+ MB
# None
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# 50%                    1.000000             7.000000          4.000000
# 75%                    4.000000             7.000000          6.000000
# max                   28.000000            25.000000         14.000000
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# count       101766.000000   101766.000000    101766.000000      101766.000000
# mean            43.095641        1.339730        16.021844           0.369357
# std             19.674362        1.705807         8.127566           1.267265
# min              1.000000        0.000000         1.000000           0.000000
# 25%             31.000000        0.000000        10.000000           0.000000
# 50%             44.000000        1.000000        15.000000           0.000000
# 75%             57.000000        2.000000        20.000000           0.000000
# max            132.000000        6.000000        81.000000          42.000000
#
#        number_emergency  number_inpatient  number_diagnoses
# count     101766.000000     101766.000000     101766.000000
# mean           0.197836          0.635566          7.422607
# std            0.930472          1.262863          1.933600
# min            0.000000          0.000000          1.000000
# 25%            0.000000          0.000000          6.000000
# 50%            0.000000          0.000000          8.000000
# 75%            0.000000          1.000000          9.000000
# max           76.000000         21.000000         16.000000

# %%
# exploring unique values in each column
# for col in df_ori.columns:
#     print(col, df_ori[col].unique())

# %%
len(df_ori['diag_3'].unique())
# Out:
# 790

# %%
df_ori.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# 0                 1    ...              No      No                   No
# 1                 3    ...              No      Up                   No
# 2                 2    ...              No      No                   No
# 3                 2    ...              No      Up                   No
# 4                 1    ...              No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
df = df_ori

# %%
# Additional features
df['service_utilization'] = df['number_outpatient'] + df['number_emergency'] + df['number_inpatient']

# %%
# standardize function
def standardize(raw_data):
    return ((raw_data - np.mean(raw_data, axis = 0)) / np.std(raw_data, axis = 0))

# %%
# calculate missing values, which indicates as '?'
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# race 2273
# gender 0
# age 0
# weight 98569
# payer_code 40256
# medical_specialty 49949
# diag_1 21
# diag_2 358
# diag_3 1423
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0
# gender 3

# %%
# calculate the readmission numbers
df['readmitted'] = df['readmitted'].replace('>30', 2)
df['readmitted'] = df['readmitted'].replace('<30', 1) #should we code it into 1 and 2?
df['readmitted'] = df['readmitted'].replace('NO', 0)

#noreadmitted = df['readmitted'][df['readmitted'] == 0].count()
print('>30 readmissions', df['readmitted'][df['readmitted'] == 2].count())
print('<30 readmissions', df['readmitted'][df['readmitted'] == 1].count())
print('no readmissions', df['readmitted'][df['readmitted'] == 0].count())
# Out:
# >30 readmissions 35545
# <30 readmissions 11357
# no readmissions 54864

# %%
# dropping discharge_disposition_id = 11, which means the patient died
# dropping the missing values in gender
# drop_Idx = set(df['race'][df['race'] == '?'].index)
drop_Idx = set(df[(df['diag_1'] == '?') & (df['diag_2'] == '?') & (df['diag_3'] == '?')].index)
drop_Idx = drop_Idx.union(set(df[df['discharge_disposition_id'] == 11].index))
drop_Idx = drop_Idx.union(set(df['gender'][df['gender'] == 'Unknown/Invalid'].index))
new_Idx = list(set(df.index) - set(drop_Idx))
df = df.iloc[new_Idx]

# %%
# dropping columns with too many missing values
df = df.drop(['weight', 'payer_code', 'medical_specialty'], axis = 1)

# %%
# remove columns having same value in each row: citoglipton, examide
df = df.drop(['citoglipton', 'examide'], axis = 1)

# %%
# code the non-numeric values
df['change'] = df['change'].replace('Ch', 1)
df['change'] = df['change'].replace('No', 0)

df['gender'] = df['gender'].replace('Male', 1)
df['gender'] = df['gender'].replace('Female', 0)

df['diabetesMed'] = df['diabetesMed'].replace('Yes', 1)
df['diabetesMed'] = df['diabetesMed'].replace('No', 0)

# code age intervals [0-10) - [90-100) from 1-10
for i in range(0,10):
    df['age'] = df['age'].replace('['+str(10*i)+'-'+str(10*(i+1))+')', i+1)

# Features have been coded
# --
# metformin, repaglinide, nateglinide, chlorpropamide, glimepiride, glipizide, glyburide, pioglitazone, 
# rosiglitazone, acarbose, miglitol, insulin, glyburide-metformin: No, Up, Down, Steady
# --
# tolazamide: No, Steady, Up
# --
# A1Cresult: >7, >8, None, Norm
# --
# max_glu_serum: >200, >300, None, Norm

keys = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide', 
        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'insulin', 'glyburide-metformin', 'tolazamide']
for col in keys:
    df[col] = df[col].replace('No', 0)
    df[col] = df[col].replace('Steady', 0)
    df[col] = df[col].replace('Up', 1)
    df[col] = df[col].replace('Down', 1) 

keys = ['metformin-pioglitazone','metformin-rosiglitazone', 'glimepiride-pioglitazone', 
        'glipizide-metformin', 'troglitazone', 'tolbutamide', 'acetohexamide']
for col in keys:
    df[col] = df[col].replace('No', 0)
    df[col] = df[col].replace('Steady', 0)  

df['A1Cresult'] = df['A1Cresult'].replace('>7', 1)
df['A1Cresult'] = df['A1Cresult'].replace('>8', 1)
df['A1Cresult'] = df['A1Cresult'].replace('Norm', 0)
df['A1Cresult'] = df['A1Cresult'].replace('None', -99)

df['max_glu_serum'] = df['max_glu_serum'].replace('>200', 1)
df['max_glu_serum'] = df['max_glu_serum'].replace('>300', 1)
df['max_glu_serum'] = df['max_glu_serum'].replace('Norm', 0)
df['max_glu_serum'] = df['max_glu_serum'].replace('None', -99)

# %%
for i in ('encounter_id', 'patient_nbr', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id',\
          'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', \
          'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose','miglitol', \
          'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', \
          'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed'):
    df[i] = df[i].astype('object')

# %%
df.dtypes
# Out:
# encounter_id                object
# patient_nbr                 object
# race                        object
# gender                      object
# age                          int64
# admission_type_id           object
# discharge_disposition_id    object
# admission_source_id         object
# time_in_hospital             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum                int64
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                   int64
# service_utilization          int64
# dtype: object

# %%
num_col = list(set(list(df._get_numeric_data().columns))- {'readmitted'})

# %%
num_col
# Out:
# ['num_medications',
#  'num_lab_procedures',
#  'max_glu_serum',
#  'num_procedures',
#  'service_utilization',
#  'number_inpatient',
#  'number_outpatient',
#  'number_emergency',
#  'age',
#  'time_in_hospital',
#  'number_diagnoses']

# %%
statdataframe = pd.DataFrame()
statdataframe['numeric_column'] = num_col
skew_before = []
skew_after = []

kurt_before = []
kurt_after = []

standard_deviation_before = []
standard_deviation_after = []

log_transform_needed = []

log_type = []

for i in num_col:
    skewval = df[i].skew()
    skew_before.append(skewval)
    
    kurtval = df[i].kurtosis()
    kurt_before.append(kurtval)
    
    sdval = df[i].std()
    standard_deviation_before.append(sdval)
    
    if (abs(skewval) >2) & (abs(kurtval) >2):
        log_transform_needed.append('Yes')
        
        if len(df[df[i] == 0])/len(df) <=0.02:
            log_type.append('log')
            skewvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).skew()
            skew_after.append(skewvalnew)
            
            kurtvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
        else:
            log_type.append('log1p')
            skewvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).skew()
            skew_after.append(skewvalnew)
        
            kurtvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
    else:
        log_type.append('NA')
        log_transform_needed.append('No')
        
        skew_after.append(skewval)
        kurt_after.append(kurtval)
        standard_deviation_after.append(sdval)

statdataframe['skew_before'] = skew_before
statdataframe['kurtosis_before'] = kurt_before
statdataframe['standard_deviation_before'] = standard_deviation_before
statdataframe['log_transform_needed'] = log_transform_needed
statdataframe['log_type'] = log_type
statdataframe['skew_after'] = skew_after
statdataframe['kurtosis_after'] = kurt_after
statdataframe['standard_deviation_after'] = standard_deviation_after

# %%
statdataframe
# Out:
#          numeric_column  skew_before  kurtosis_before  \
# 0       num_medications     1.333039         3.523472
# 1    num_lab_procedures    -0.241491        -0.253099
# 2         max_glu_serum     4.027247        14.219538
# 3        num_procedures     1.326020         0.890773
# 4   service_utilization     5.334724        67.779770
# 5      number_inpatient     3.626402        20.833542
# 6     number_outpatient     8.818291       148.558544
# 7      number_emergency    22.842251      1185.246374
# 8                   age    -0.626715         0.274302
# 9      time_in_hospital     1.137931         0.871189
# 10     number_diagnoses    -0.867785        -0.109005
#
#     standard_deviation_before log_transform_needed log_type  skew_after  \
# 0                    8.092612                   No       NA    1.333039
# 1                   19.620228                   No       NA   -0.241491
# 2                   22.131312                  Yes    log1p   -0.029485
# 3                    1.700335                   No       NA    1.326020
# 4                    2.292730                  Yes    log1p    1.119136
# 5                    1.261825                  Yes    log1p    1.450492
# 6                    1.263973                  Yes    log1p    2.733914
# 7                    0.935517                  Yes    log1p    3.661064
# 8                    1.594750                   No       NA   -0.626715
# 9                    2.974528                   No       NA    1.137931
# 10                   1.938211                   No       NA   -0.867785
#
#     kurtosis_after  standard_deviation_after
# 0         3.523472                  8.092612
# 1        -0.253099                 19.620228
# 2        -1.999896                  0.346569
# 3         0.890773                  1.700335
# 4         0.547353                  0.662373
# 5         1.405364                  0.510433
# 6         7.804218                  0.429394
# 7        16.276610                  0.315405
# 8         0.274302                  1.594750
# 9         0.871189                  2.974528
# 10       -0.109005                  1.938211

# %%
# performing the log transformation for the columns determined to be needing it above.

for i in range(len(statdataframe)):
    if statdataframe['log_transform_needed'][i] == 'Yes':
        colname = str(statdataframe['numeric_column'][i])
        
        if statdataframe['log_type'][i] == 'log':
            df = df[df[colname] > 0]
            df[colname + "_log"] = np.log(df[colname])
            
        elif statdataframe['log_type'][i] == 'log1p':
            df = df[df[colname] >= 0]
            df[colname + "_log1p"] = np.log1p(df[colname])

# %%
ruledict = {
    "encounter_id": "count",
    "race": "first",
    "gender": "first",
    "age": "first", #last
    "admission_type_id" : "first",
    "discharge_disposition_id" : "first",
    "admission_source_id" : "first",
    "time_in_hospital": "mean",
    "num_lab_procedures" : "mean",
    "num_procedures" : "mean",
    "num_medications" : "mean",
    "number_outpatient" : "mean",
    "number_emergency" : "mean", 
    "number_inpatient" : "mean",
    "diag_1" : ','.join,
    "diag_2" : ','.join,
    "diag_3" : ','.join,
    "number_diagnoses" : "mean", 
    "max_glu_serum" : ','.join,
    "A1Cresult" : ','.join,
#     "metformin" : ','.join,
#     "repaglinide" : ','.join,
#     "nateglinide" : ','.join,
#     "chlorpropamide" : ','.join,
#     "glimepiride" : ','.join,
#     "acetohexamide" : "mean",
#     "glipizide" : ','.join,
#     "glyburide" : ','.join,
#     "tolbutamide" : "mean",
#     "pioglitazone" : ','.join,
#     "rosiglitazone" : ','.join,
#     "acarbose" : ','.join,
#     "miglitol" : ','.join,
#     "troglitazone" : "mean",
#     "tolazamide" : ','.join,
#     "insulin" : ','.join,
#     "glyburide-metformin" : ','.join,
#     "glipizide-metformin" : "mean",
#     "glimepiride-pioglitazone" : "mean",
#     "metformin-rosiglitazone" : "mean",
#     "metformin-pioglitazone" : "mean",
    "change" : "mean",
    "diabetesMed": "mean",
    "readmitted" : "mean",
    "service_utilization" : "mean"
}

# %%
df_p = df.groupby('patient_nbr').agg(ruledict).reset_index(drop = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    2809             try:
# -> 2810                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    2811             except Exception:
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     853         if len(output) == 0:
# --> 854             return self._python_apply_general(f)
#     855
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in _python_apply_general(self, f)
#     719         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 720                                                    self.axis)
#     721
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, f, data, axis)
#    1728             group_axes = _get_axes(group)
# -> 1729             res = f(group)
#    1730             if not _is_indexed_like(res, group_axes):
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in <lambda>(x)
#     841         func = self._is_builtin_func(func)
# --> 842         f = lambda x: func(x, *args, **kwargs)
#     843
#
# TypeError: sequence item 0: expected str instance, numpy.int64 found
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-294dc18ceb85> in <module>()
# ----> 1 df_p = df.groupby('patient_nbr').agg(ruledict).reset_index(drop = True)
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3959         versionadded=''))
#    3960     def aggregate(self, arg, *args, **kwargs):
# -> 3961         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3962
#    3963     agg = aggregate
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3391
#    3392         _level = kwargs.pop('_level', None)
# -> 3393         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3394         if how is None:
#    3395             return result
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     563
#     564                 try:
# --> 565                     result = _agg(arg, _agg_1dim)
#     566                 except SpecificationError:
#     567
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/base.py in _agg(arg, func)
#     514                 result = compat.OrderedDict()
#     515                 for fname, agg_how in compat.iteritems(arg):
# --> 516                     result[fname] = func(fname, agg_how)
#     517                 return result
#     518
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/base.py in _agg_1dim(name, how, subset)
#     497                     raise SpecificationError("nested dictionary is ambiguous "
#     498                                              "in aggregation")
# --> 499                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     500
#     501             def _agg_2dim(name, how):
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    2810                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    2811             except Exception:
# -> 2812                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#    2813
#    2814             index = Index(sorted(result), name=self.grouper.names[0])
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in _aggregate_named(self, func, *args, **kwargs)
#    2940         for name, group in self:
#    2941             group.name = name
# -> 2942             output = func(group, *args, **kwargs)
#    2943             if isinstance(output, (Series, Index, np.ndarray)):
#    2944                 raise Exception('Must produce aggregated value')
#
# TypeError: sequence item 0: expected str instance, numpy.int64 found

# %%
df_p = gb_patient.agg().reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    2809             try:
# -> 2810                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    2811             except Exception:
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     853         if len(output) == 0:
# --> 854             return self._python_apply_general(f)
#     855
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in _python_apply_general(self, f)
#     719         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 720                                                    self.axis)
#     721
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, f, data, axis)
#    1728             group_axes = _get_axes(group)
# -> 1729             res = f(group)
#    1730             if not _is_indexed_like(res, group_axes):
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in <lambda>(x)
#     841         func = self._is_builtin_func(func)
# --> 842         f = lambda x: func(x, *args, **kwargs)
#     843
#
# TypeError: sequence item 0: expected str instance, numpy.int64 found
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-0ced426fc70b> in <module>()
#      44     "diabetesMed": "mean",
#      45     "readmitted" : "mean",
# ---> 46     "service_utilization" : "mean"
#      47 }).reset_index()
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3959         versionadded=''))
#    3960     def aggregate(self, arg, *args, **kwargs):
# -> 3961         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3962
#    3963     agg = aggregate
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3391
#    3392         _level = kwargs.pop('_level', None)
# -> 3393         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3394         if how is None:
#    3395             return result
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     563
#     564                 try:
# --> 565                     result = _agg(arg, _agg_1dim)
#     566                 except SpecificationError:
#     567
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/base.py in _agg(arg, func)
#     514                 result = compat.OrderedDict()
#     515                 for fname, agg_how in compat.iteritems(arg):
# --> 516                     result[fname] = func(fname, agg_how)
#     517                 return result
#     518
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/base.py in _agg_1dim(name, how, subset)
#     497                     raise SpecificationError("nested dictionary is ambiguous "
#     498                                              "in aggregation")
# --> 499                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     500
#     501             def _agg_2dim(name, how):
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    2810                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    2811             except Exception:
# -> 2812                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#    2813
#    2814             index = Index(sorted(result), name=self.grouper.names[0])
#
# /Users/t_shahh/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in _aggregate_named(self, func, *args, **kwargs)
#    2940         for name, group in self:
#    2941             group.name = name
# -> 2942             output = func(group, *args, **kwargs)
#    2943             if isinstance(output, (Series, Index, np.ndarray)):
#    2944                 raise Exception('Must produce aggregated value')
#
# TypeError: sequence item 0: expected str instance, numpy.int64 found

# %%
df_p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-3aa53a090e47> in <module>()
# ----> 1 df_p
#
# NameError: name 'df_p' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5225 entries, 133 to 101413
# Data columns (total 51 columns):
# encounter_id                 5225 non-null object
# patient_nbr                  5225 non-null object
# race                         5225 non-null object
# gender                       5225 non-null object
# age                          5225 non-null int64
# admission_type_id            5225 non-null object
# discharge_disposition_id     5225 non-null object
# admission_source_id          5225 non-null object
# time_in_hospital             5225 non-null int64
# num_lab_procedures           5225 non-null int64
# num_procedures               5225 non-null int64
# num_medications              5225 non-null int64
# number_outpatient            5225 non-null int64
# number_emergency             5225 non-null int64
# number_inpatient             5225 non-null int64
# diag_1                       5225 non-null object
# diag_2                       5225 non-null object
# diag_3                       5225 non-null object
# number_diagnoses             5225 non-null int64
# max_glu_serum                5225 non-null int64
# A1Cresult                    5225 non-null object
# metformin                    5225 non-null object
# repaglinide                  5225 non-null object
# nateglinide                  5225 non-null object
# chlorpropamide               5225 non-null object
# glimepiride                  5225 non-null object
# acetohexamide                5225 non-null object
# glipizide                    5225 non-null object
# glyburide                    5225 non-null object
# tolbutamide                  5225 non-null object
# pioglitazone                 5225 non-null object
# rosiglitazone                5225 non-null object
# acarbose                     5225 non-null object
# miglitol                     5225 non-null object
# troglitazone                 5225 non-null object
# tolazamide                   5225 non-null object
# insulin                      5225 non-null object
# glyburide-metformin          5225 non-null object
# glipizide-metformin          5225 non-null object
# glimepiride-pioglitazone     5225 non-null object
# metformin-rosiglitazone      5225 non-null object
# metformin-pioglitazone       5225 non-null object
# change                       5225 non-null object
# diabetesMed                  5225 non-null object
# readmitted                   5225 non-null int64
# service_utilization          5225 non-null int64
# max_glu_serum_log1p          5225 non-null float64
# service_utilization_log1p    5225 non-null float64
# number_inpatient_log1p       5225 non-null float64
# number_outpatient_log1p      5225 non-null float64
# number_emergency_log1p       5225 non-null float64
# dtypes: float64(5), int64(12), object(34)
# memory usage: 2.1+ MB

# %%
df.shape
# Out:
# (5225, 51)

# %%
for col in df.columns:
    if df[col].dtype == 'int64':
         print(col,df[col].skew(), df[col].kurtosis())
# Out:
# age -0.652955420447 -0.0333082864308
# time_in_hospital 1.01816501621 0.570524589246
# num_lab_procedures 1.40252644094 1.05150352927
# num_procedures 1.7932612627 3.53900826163
# num_medications 0.663772789719 0.438123765079
# number_outpatient 5.2564625314 80.5799251688
# number_emergency 8.74964817733 168.001035057
# number_inpatient 3.94507567405 26.3462167051
# number_diagnoses -0.611097237289 -0.542949842873
# max_glu_serum -0.0294853505675 -1.99989627124
# readmitted 0.265221228952 -1.77987471601
# service_utilization 3.15826658749 19.5763383577

# %%
import seaborn as sns
from matplotlib.colors import ListedColormap
# my_cmap = ListedColormap(sns.color_palette("RdYlGn", n_colors=15).as_hex())
# my_cmap = ListedColormap(sns.diverging_palette(150, 250, sep=120, n=28, center="light").as_hex())

my_cmap = ListedColormap(sns.light_palette((250, 100, 50), input="husl", n_colors=50).as_hex())
# drop some columns due to their means is round to 0
table = df.drop(['acetohexamide','tolbutamide', 'troglitazone', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone','patient_nbr', 'encounter_id'], axis = 1).corr(method='pearson')
table.style.background_gradient(cmap=my_cmap, axis = 0)
# Out:
# <style  type="text/css" >
#     #T_25229982_cfe3_11e7_95ee_720003188670row0_col0 {
#             background-color:  #007ad1;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col1 {
#             background-color:  #c5e3f8;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col2 {
#             background-color:  #c5e3f8;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col3 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col4 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col5 {
#             background-color:  #c5e3f8;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col6 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col7 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col8 {
#             background-color:  #91c7ee;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col9 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col10 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col11 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col12 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col13 {
#             background-color:  #ddf0fd;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col14 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col15 {
#             background-color:  #bbdef6;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row0_col16 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col0 {
#             background-color:  #b7dbf6;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col1 {
#             background-color:  #007ad1;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col2 {
#             background-color:  #83c0eb;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col3 {
#             background-color:  #96caef;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col4 {
#             background-color:  #71b6e7;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col5 {
#             background-color:  #d4ebfb;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col6 {
#             background-color:  #cee8fa;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col7 {
#             background-color:  #bbdef6;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col8 {
#             background-color:  #9fcff1;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col9 {
#             background-color:  #aed7f4;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col10 {
#             background-color:  #cee8fa;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col11 {
#             background-color:  #cae5f9;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col12 {
#             background-color:  #aed7f4;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col13 {
#             background-color:  #cae5f9;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col14 {
#             background-color:  #c1e1f8;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col15 {
#             background-color:  #cee8fa;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row1_col16 {
#             background-color:  #cee8fa;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col0 {
#             background-color:  #d8edfc;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col1 {
#             background-color:  #9bccf0;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col2 {
#             background-color:  #007ad1;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col3 {
#             background-color:  #cee8fa;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col4 {
#             background-color:  #e1f2fe;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col5 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col6 {
#             background-color:  #ddf0fd;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col7 {
#             background-color:  #bbdef6;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col8 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col9 {
#             background-color:  #b2d9f5;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col10 {
#             background-color:  #bbdef6;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col11 {
#             background-color:  #e1f2fe;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col12 {
#             background-color:  #b2d9f5;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col13 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col14 {
#             background-color:  #c5e3f8;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col15 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row2_col16 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col0 {
#             background-color:  #cee8fa;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col1 {
#             background-color:  #91c7ee;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col2 {
#             background-color:  #a9d4f3;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col3 {
#             background-color:  #007ad1;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col4 {
#             background-color:  #9bccf0;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col5 {
#             background-color:  #c1e1f8;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col6 {
#             background-color:  #cee8fa;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col7 {
#             background-color:  #cae5f9;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col8 {
#             background-color:  #aed7f4;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col9 {
#             background-color:  #d4ebfb;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col10 {
#             background-color:  #e6f4ff;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col11 {
#             background-color:  #cee8fa;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col12 {
#             background-color:  #d4ebfb;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col13 {
#             background-color:  #cee8fa;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col14 {
#             background-color:  #d8edfc;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col15 {
#             background-color:  #bbdef6;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row3_col16 {
#             background-color:  #d4ebfb;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row4_col0 {
#             background-color:  #c5e3f8;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row4_col1 {
#             background-color:  #67b0e5;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row4_col2 {
#             background-color:  #b2d9f5;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row4_col3 {
#             background-color:  #91c7ee;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row4_col4 {
#             background-color:  #007ad1;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row4_col5 {
#             background-color:  #b7dbf6;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row4_col6 {
#             background-color:  #c1e1f8;
#         }    #T_25229982_cfe3_11e7_95ee_720003188670row4_col7 {
#             background-color:  #bbdef6;
#         }    #T_25229982_cfe3_11e7_95ee_72000318867
