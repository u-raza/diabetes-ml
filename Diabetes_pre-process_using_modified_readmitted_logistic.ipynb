# %%
import IPython
import pandas as pd
import numpy as np
from statistics import mode
import matplotlib.pyplot as plt  
from sklearn.preprocessing import MinMaxScaler

# %%
# load modified file with some pre-processing completed
df = pd.read_csv("modify.csv", index_col=0)
df.shape
# Out:
# (100120, 52)

# %%
df.head(10).T
# Out:
#                                   0          1                2          3  \
# encounter_id                2278392     149190            64410     500364
# patient_nbr                 8222157   55629189         86047875   82442376
# race                      Caucasian  Caucasian  AfricanAmerican  Caucasian
# gender                            0          0                0          1
# age                               1          2                3          4
# admission_type_id                 6          1                1          1
# discharge_disposition_id         25          1                1          1
# admission_source_id               1          7                7          7
# time_in_hospital                  1          3                2          2
# num_lab_procedures               41         59               11         44
# num_procedures                    0          0                5          1
# num_medications                   1         18               13         16
# number_outpatient                 0          0                2          0
# number_emergency                  0          0                0          0
# number_inpatient                  0          0                1          0
# diag_1                       250.83        276              648          8
# diag_2                            ?     250.01              250     250.43
# diag_3                            ?        255              V27        403
# number_diagnoses                  1          9                6          7
# max_glu_serum                   -99        -99              -99        -99
# A1Cresult                       -99        -99              -99        -99
# metformin                         0          0                0          0
# repaglinide                       0          0                0          0
# nateglinide                       0          0                0          0
# chlorpropamide                    0          0                0          0
# glimepiride                       0          0                0          0
# acetohexamide                     0          0                0          0
# glipizide                         0          0                0          0
# glyburide                         0          0                0          0
# tolbutamide                       0          0                0          0
# pioglitazone                      0          0                0          0
# rosiglitazone                     0          0                0          0
# acarbose                          0          0                0          0
# miglitol                          0          0                0          0
# troglitazone                      0          0                0          0
# tolazamide                        0          0                0          0
# insulin                           0          1                0          1
# glyburide-metformin               0          0                0          0
# glipizide-metformin               0          0                0          0
# glimepiride-pioglitazone          0          0                0          0
# metformin-rosiglitazone           0          0                0          0
# metformin-pioglitazone            0          0                0          0
# change                            0          1                0          1
# diabetesMed                       0          1                1          1
# readmitted                        0          2                0          0
# service_utilization               0          0                3          0
# level1_diag1                      4          0                0          0
# level2_diag1                     14         20                0          0
# level1_diag2                      0          4                4          4
# level2_diag2                      0         14               14         14
# level1_diag3                      0          0                0          1
# level2_diag3                      0         20                0          2
#
#                                   4          5          6          7  \
# encounter_id                  16680      35754      55842      63768
# patient_nbr                42519267   82637451   84259809  114882984
# race                      Caucasian  Caucasian  Caucasian  Caucasian
# gender                            1          1          1          1
# age                               5          6          7          8
# admission_type_id                 1          2          3          1
# discharge_disposition_id          1          1          1          1
# admission_source_id               7          2          2          7
# time_in_hospital                  1          3          4          5
# num_lab_procedures               51         31         70         73
# num_procedures                    0          6          1          0
# num_medications                   8         16         21         12
# number_outpatient                 0          0          0          0
# number_emergency                  0          0          0          0
# number_inpatient                  0          0          0          0
# diag_1                          197        414        414        428
# diag_2                          157        411        411        492
# diag_3                          250        250        V45        250
# number_diagnoses                  5          9          7          8
# max_glu_serum                   -99        -99        -99        -99
# A1Cresult                       -99        -99        -99        -99
# metformin                         0          0          0          0
# repaglinide                       0          0          0          0
# nateglinide                       0          0          0          0
# chlorpropamide                    0          0          0          0
# glimepiride                       0          0          0          0
# acetohexamide                     0          0          0          0
# glipizide                         0          0          0          0
# glyburide                         0          0          0          0
# tolbutamide                       0          0          0          0
# pioglitazone                      0          0          0          0
# rosiglitazone                     0          0          0          0
# acarbose                          0          0          0          0
# miglitol                          0          0          0          0
# troglitazone                      0          0          0          0
# tolazamide                        0          0          0          0
# insulin                           0          0          0          0
# glyburide-metformin               0          0          0          0
# glipizide-metformin               0          0          0          0
# glimepiride-pioglitazone          0          0          0          0
# metformin-rosiglitazone           0          0          0          0
# metformin-pioglitazone            0          0          0          0
# change                            1          0          1          0
# diabetesMed                       1          1          1          1
# readmitted                        0          2          0          2
# service_utilization               0          0          0          0
# level1_diag1                      8          1          1          1
# level2_diag1                     19          2          2          3
# level1_diag2                      8          1          1          2
# level2_diag2                     19          2          2          6
# level1_diag3                      4          4          0          4
# level2_diag3                     14         14          0         14
#
#                                   8          9
# encounter_id                  12522      15738
# patient_nbr                48330783   63555939
# race                      Caucasian  Caucasian
# gender                            0          0
# age                               9         10
# admission_type_id                 2          3
# discharge_disposition_id          1          3
# admission_source_id               4          4
# time_in_hospital                 13         12
# num_lab_procedures               68         33
# num_procedures                    2          3
# num_medications                  28         18
# number_outpatient                 0          0
# number_emergency                  0          0
# number_inpatient                  0          0
# diag_1                          398        434
# diag_2                          427        198
# diag_3                           38        486
# number_diagnoses                  8          8
# max_glu_serum                   -99        -99
# A1Cresult                       -99        -99
# metformin                         0          0
# repaglinide                       0          0
# nateglinide                       0          0
# chlorpropamide                    0          0
# glimepiride                       0          0
# acetohexamide                     0          0
# glipizide                         0          0
# glyburide                         0          0
# tolbutamide                       0          0
# pioglitazone                      0          0
# rosiglitazone                     0          0
# acarbose                          0          0
# miglitol                          0          0
# troglitazone                      0          0
# tolazamide                        0          0
# insulin                           0          0
# glyburide-metformin               0          0
# glipizide-metformin               0          0
# glimepiride-pioglitazone          0          0
# metformin-rosiglitazone           0          0
# metformin-pioglitazone            0          0
# change                            1          1
# diabetesMed                       1          1
# readmitted                        0          0
# service_utilization               0          0
# level1_diag1                      1          1
# level2_diag1                      1          3
# level1_diag2                      1          8
# level2_diag2                      3         19
# level1_diag3                      0          2
# level2_diag3                      0          5

# %%
# convert data type of nominal features in dataframe to 'object' type
for i in ('encounter_id', 'patient_nbr', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id',\
          'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', \
          'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose','miglitol', \
          'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', \
          'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed', \
          'age', 'A1Cresult', 'max_glu_serum', 'level1_diag1', 'level1_diag2', 'level1_diag3', 'level2_diag1', 'level2_diag2', 'level2_diag3' ):
    df[i] = df[i].astype('object')

# %%
df.dtypes
# Out:
# encounter_id                object
# patient_nbr                 object
# race                        object
# gender                      object
# age                         object
# admission_type_id           object
# discharge_disposition_id    object
# admission_source_id         object
# time_in_hospital             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                   int64
# service_utilization          int64
# level1_diag1                object
# level2_diag1                object
# level1_diag2                object
# level2_diag2                object
# level1_diag3                object
# level2_diag3                object
# dtype: object

# %%
"""
This code converts age as categorical variable to a continuous approximation by assuming mid-point of each age-category as
the actual age value. This is done to avoid having to deal with age as a dummy variable in the models which makes
interpretation very cumbersome. Also, since age category is not purely nominal but ordinal, we do not want to lose that
information by treating it as a simple categorical variable.
"""

# convert age back to integer type
df['age'] = df['age'].astype('int64')
print(df.age.value_counts())
# convert age categories to mid-point values
age_dict = {1:5, 2:15, 3:25, 4:35, 5:45, 6:55, 7:65, 8:75, 9:85, 10:95}
df['age'] = df.age.map(age_dict)
print(df.age.value_counts())
# Out:
# 8     25564
# 7     22186
# 6     17102
# 9     16708
# 5      9626
# 4      3765
# 10     2669
# 3      1650
# 2       690
# 1       160
# Name: age, dtype: int64
# 75    25564
# 65    22186
# 55    17102
# 85    16708
# 45     9626
# 35     3765
# 95     2669
# 25     1650
# 15      690
# 5       160
# Name: age, dtype: int64

# %%
# get list of only numeric features
num_col = list(set(list(df._get_numeric_data().columns))- {'readmitted'})

# %%
num_col
# Out:
# ['number_inpatient',
#  'service_utilization',
#  'age',
#  'number_outpatient',
#  'number_emergency',
#  'number_diagnoses',
#  'time_in_hospital',
#  'num_medications',
#  'num_procedures',
#  'num_lab_procedures']

# %%
# Removing skewnewss and kurtosis using log transformation if it is above a threshold value (2)

statdataframe = pd.DataFrame()
statdataframe['numeric_column'] = num_col
skew_before = []
skew_after = []

kurt_before = []
kurt_after = []

standard_deviation_before = []
standard_deviation_after = []

log_transform_needed = []

log_type = []

for i in num_col:
    skewval = df[i].skew()
    skew_before.append(skewval)
    
    kurtval = df[i].kurtosis()
    kurt_before.append(kurtval)
    
    sdval = df[i].std()
    standard_deviation_before.append(sdval)
    
    if (abs(skewval) >2) & (abs(kurtval) >2):
        log_transform_needed.append('Yes')
        
        if len(df[df[i] == 0])/len(df) <=0.02:
            log_type.append('log')
            skewvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).skew()
            skew_after.append(skewvalnew)
            
            kurtvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
        else:
            log_type.append('log1p')
            skewvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).skew()
            skew_after.append(skewvalnew)
        
            kurtvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
    else:
        log_type.append('NA')
        log_transform_needed.append('No')
        
        skew_after.append(skewval)
        kurt_after.append(kurtval)
        standard_deviation_after.append(sdval)

statdataframe['skew_before'] = skew_before
statdataframe['kurtosis_before'] = kurt_before
statdataframe['standard_deviation_before'] = standard_deviation_before
statdataframe['log_transform_needed'] = log_transform_needed
statdataframe['log_type'] = log_type
statdataframe['skew_after'] = skew_after
statdataframe['kurtosis_after'] = kurt_after
statdataframe['standard_deviation_after'] = standard_deviation_after

# %%
statdataframe
# Out:
#         numeric_column  skew_before  kurtosis_before  \
# 0     number_inpatient     3.626402        20.833542
# 1  service_utilization     5.334724        67.779770
# 2                  age    -0.626715         0.274302
# 3    number_outpatient     8.818291       148.558544
# 4     number_emergency    22.842251      1185.246374
# 5     number_diagnoses    -0.867785        -0.109005
# 6     time_in_hospital     1.137931         0.871189
# 7      num_medications     1.333039         3.523472
# 8       num_procedures     1.326020         0.890773
# 9   num_lab_procedures    -0.241491        -0.253099
#
#    standard_deviation_before log_transform_needed log_type  skew_after  \
# 0                   1.261825                  Yes    log1p    1.450492
# 1                   2.292730                  Yes    log1p    1.119136
# 2                  15.947496                   No       NA   -0.626715
# 3                   1.263973                  Yes    log1p    2.733914
# 4                   0.935517                  Yes    log1p    3.661064
# 5                   1.938211                   No       NA   -0.867785
# 6                   2.974528                   No       NA    1.137931
# 7                   8.092612                   No       NA    1.333039
# 8                   1.700335                   No       NA    1.326020
# 9                  19.620228                   No       NA   -0.241491
#
#    kurtosis_after  standard_deviation_after
# 0        1.405364                  0.510433
# 1        0.547353                  0.662373
# 2        0.274302                 15.947496
# 3        7.804218                  0.429394
# 4       16.276610                  0.315405
# 5       -0.109005                  1.938211
# 6        0.871189                  2.974528
# 7        3.523472                  8.092612
# 8        0.890773                  1.700335
# 9       -0.253099                 19.620228

# %%
# performing the log transformation for the columns determined to be needing it above.

for i in range(len(statdataframe)):
    if statdataframe['log_transform_needed'][i] == 'Yes':
        colname = str(statdataframe['numeric_column'][i])
        
        if statdataframe['log_type'][i] == 'log':
            df = df[df[colname] > 0]
            df[colname + "_log"] = np.log(df[colname])
            
        elif statdataframe['log_type'][i] == 'log1p':
            df = df[df[colname] >= 0]
            df[colname + "_log1p"] = np.log1p(df[colname])

# %%
df = df.drop(['number_outpatient', 'number_inpatient', 'number_emergency','service_utilization'], axis = 1)

# %%
df.shape
# Out:
# (100120, 52)

# %%
# get list of only numeric features
numerics = list(set(list(df._get_numeric_data().columns))- {'readmitted'})

# %%
numerics
# Out:
# ['age',
#  'number_diagnoses',
#  'time_in_hospital',
#  'num_medications',
#  'num_procedures',
#  'service_utilization_log1p',
#  'number_inpatient_log1p',
#  'number_outpatient_log1p',
#  'number_emergency_log1p',
#  'num_lab_procedures']

# %%
# show list of features that are categorical
df.encounter_id = df.encounter_id.astype('int64')
df.patient_nbr = df.patient_nbr.astype('int64')
df.diabetesMed = df.diabetesMed.astype('int64')
df.change = df.change.astype('int64')

# convert data type of nominal features in dataframe to 'object' type for aggregating
for i in ('metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', \
          'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose','miglitol', \
          'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', \
          'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone','A1Cresult'):
    df[i] = df[i].astype('int64')

df.dtypes
# Out:
# encounter_id                   int64
# patient_nbr                    int64
# race                          object
# gender                        object
# age                            int64
# admission_type_id             object
# discharge_disposition_id      object
# admission_source_id           object
# time_in_hospital               int64
# num_lab_procedures             int64
# num_procedures                 int64
# num_medications                int64
# diag_1                        object
# diag_2                        object
# diag_3                        object
# number_diagnoses               int64
# max_glu_serum                 object
# A1Cresult                      int64
# metformin                      int64
# repaglinide                    int64
# nateglinide                    int64
# chlorpropamide                 int64
# glimepiride                    int64
# acetohexamide                  int64
# glipizide                      int64
# glyburide                      int64
# tolbutamide                    int64
# pioglitazone                   int64
# rosiglitazone                  int64
# acarbose                       int64
# miglitol                       int64
# troglitazone                   int64
# tolazamide                     int64
# insulin                        int64
# glyburide-metformin            int64
# glipizide-metformin            int64
# glimepiride-pioglitazone       int64
# metformin-rosiglitazone        int64
# metformin-pioglitazone         int64
# change                         int64
# diabetesMed                    int64
# readmitted                     int64
# level1_diag1                  object
# level2_diag1                  object
# level1_diag2                  object
# level2_diag2                  object
# level1_diag3                  object
# level2_diag3                  object
# number_inpatient_log1p       float64
# service_utilization_log1p    float64
# number_outpatient_log1p      float64
# number_emergency_log1p       float64
# dtype: object

# %%
df.A1Cresult.value_counts()
# Out:
# -99    83243
#  1     11935
#  0      4942
# Name: A1Cresult, dtype: int64

# %%
"""
For dealing with multiple encounters of same patient, we collapse these multiple encounters into a single one, such that
the resultant encounter retains the key features of its constituents. For situations where this could not be achieved
effectively, we have dropped those patients altogether. An example is where the category of primary diagnosis
(not exact disease) is different across multiple encounters of the same patient.
"""
# create a rule dictionary for combining patient records with multiple encounters

ruledict = {
    "patient_nbr":"first",
    "race": "first",
    "gender": "first",
    "age": "mean",
    "admission_type_id" : "first",
    "discharge_disposition_id" : "first",
    "admission_source_id" : "first",
    "time_in_hospital": "mean",
    "num_lab_procedures" : "mean",
    "num_procedures" : "mean",
    "num_medications" : "mean",
    "number_outpatient_log1p" : "mean",
    "number_emergency_log1p" : "mean", 
    "number_inpatient_log1p" : "mean",
    "diag_1" : ','.join,
    "diag_2" : ','.join,
    "diag_3" : ','.join,
    "number_diagnoses" : "mean", 
    "max_glu_serum" : "mean",
    "A1Cresult" : "mean",
    "metformin" : "mean",
    "repaglinide" : "mean",
    "nateglinide" : "mean",
    "chlorpropamide" : "mean",
    "glimepiride" : "mean",
    "acetohexamide" : "mean",
    "glipizide" : "mean",
    "glyburide" : "mean",
    "tolbutamide" : "mean",
    "pioglitazone" : "mean",
    "rosiglitazone" : "mean",
    "acarbose" : "mean",
    "miglitol" : "mean",
    "troglitazone" : "mean",
    "tolazamide" : "mean",
    "insulin" : "mean",
    "glyburide-metformin" : "mean",
    "glipizide-metformin" : "mean",
    "glimepiride-pioglitazone" : "mean",
    "metformin-rosiglitazone" : "mean",
    "metformin-pioglitazone" : "mean",
    "change" : lambda x: 1 if np.sum(x) >= 1 else 0, # if any encounter has a change, then composite encounter has change
    "diabetesMed": "mean", # gives proportion of change as this is a binary variable
    "readmitted" : "mean", # simialr logic as above but here values range = 0-2
    "service_utilization_log1p" : "mean",
    "level1_diag1": lambda x: x.iloc[0] if x.nunique()==1 else np.NaN,
    "level1_diag2": lambda x: x.iloc[0] if x.nunique()==1 else np.NaN,
    "level1_diag3": lambda x: x.iloc[0] if x.nunique()==1 else np.NaN,
    "level2_diag1": lambda x: x.iloc[0] if x.nunique()==1 else np.NaN,
    "level2_diag2": lambda x: x.iloc[0] if x.nunique()==1 else np.NaN,
    "level2_diag3": lambda x: x.iloc[0] if x.nunique()==1 else np.NaN,
    "max_glu_serum": lambda x: x.max(),
    "A1Cresult": lambda x: x.max(),
}

# %%
df_p = df.groupby('patient_nbr').agg(ruledict).reset_index(drop = True)

# %%
df_p[df_p.patient_nbr==5220].T
# Out:
#                                            12
# patient_nbr                              5220
# race                                Caucasian
# gender                                      1
# age                                      72.5
# admission_type_id                           1
# discharge_disposition_id                    1
# admission_source_id                         7
# time_in_hospital                          5.5
# num_lab_procedures                      41.25
# num_procedures                           1.75
# num_medications                            15
# number_outpatient_log1p                     0
# number_emergency_log1p                      0
# number_inpatient_log1p               0.722593
# diag_1                      276,404,682,250.7
# diag_2                     426,427,250.41,707
# diag_3                        558,276,403,428
# number_diagnoses                            9
# max_glu_serum                             -99
# A1Cresult                                   1
# metformin                                   0
# repaglinide                                 0
# nateglinide                                 0
# chlorpropamide                              0
# glimepiride                                 0
# acetohexamide                               0
# glipizide                                   0
# glyburide                                   0
# tolbutamide                                 0
# pioglitazone                                0
# rosiglitazone                               0
# acarbose                                    0
# miglitol                                    0
# troglitazone                                0
# tolazamide                                  0
# insulin                                     0
# glyburide-metformin                         0
# glipizide-metformin                         0
# glimepiride-pioglitazone                    0
# metformin-rosiglitazone                     0
# metformin-pioglitazone                      0
# change                                      0
# diabetesMed                                 1
# readmitted                                1.5
# service_utilization_log1p            0.722593
# level1_diag1                              NaN
# level1_diag2                              NaN
# level1_diag3                              NaN
# level2_diag1                              NaN
# level2_diag2                              NaN
# level2_diag3                              NaN

# %%
import scipy as sp
df = df[(np.abs(sp.stats.zscore(df[numerics])) < 3).all(axis=1)]

# %%
# apply minimax scaling to all numeric features
for feature in numerics:
    scaler = MinMaxScaler()
    df[numerics] = scaler.fit_transform(df[numerics])

# %%
df_p.isnull().sum()
# Out:
# patient_nbr                      0
# race                             0
# gender                           0
# age                              0
# admission_type_id                0
# discharge_disposition_id         0
# admission_source_id              0
# time_in_hospital                 0
# num_lab_procedures               0
# num_procedures                   0
# num_medications                  0
# number_outpatient_log1p          0
# number_emergency_log1p           0
# number_inpatient_log1p           0
# diag_1                           0
# diag_2                           0
# diag_3                           0
# number_diagnoses                 0
# max_glu_serum                    0
# A1Cresult                        0
# metformin                        0
# repaglinide                      0
# nateglinide                      0
# chlorpropamide                   0
# glimepiride                      0
# acetohexamide                    0
# glipizide                        0
# glyburide                        0
# tolbutamide                      0
# pioglitazone                     0
# rosiglitazone                    0
# acarbose                         0
# miglitol                         0
# troglitazone                     0
# tolazamide                       0
# insulin                          0
# glyburide-metformin              0
# glipizide-metformin              0
# glimepiride-pioglitazone         0
# metformin-rosiglitazone          0
# metformin-pioglitazone           0
# change                           0
# diabetesMed                      0
# readmitted                       0
# service_utilization_log1p        0
# level1_diag1                 11612
# level1_diag2                 12078
# level1_diag3                 12873
# level2_diag1                 12933
# level2_diag2                 13522
# level2_diag3                 14214
# dtype: int64

# %%
# drop the records where multiple encounters had dis-similar diagnoses
df_p = df_p.drop(df_p[(df_p.level1_diag1.isnull())].index)
df_p.shape
# Out:
# (58830, 51)

# %%
df_p.isnull().sum()
# Out:
# patient_nbr                     0
# race                            0
# gender                          0
# age                             0
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient_log1p         0
# number_emergency_log1p          0
# number_inpatient_log1p          0
# diag_1                          0
# diag_2                          0
# diag_3                          0
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# chlorpropamide                  0
# glimepiride                     0
# acetohexamide                   0
# glipizide                       0
# glyburide                       0
# tolbutamide                     0
# pioglitazone                    0
# rosiglitazone                   0
# acarbose                        0
# miglitol                        0
# troglitazone                    0
# tolazamide                      0
# insulin                         0
# glyburide-metformin             0
# glipizide-metformin             0
# glimepiride-pioglitazone        0
# metformin-rosiglitazone         0
# metformin-pioglitazone          0
# change                          0
# diabetesMed                     0
# readmitted                      0
# service_utilization_log1p       0
# level1_diag1                    0
# level1_diag2                 2962
# level1_diag3                 3424
# level2_diag1                 1321
# level2_diag2                 3532
# level2_diag3                 3904
# dtype: int64

# %%
df_p.drop(['level1_diag2','level1_diag3','level2_diag1','level2_diag2','level2_diag3','diag_1','diag_2','diag_3'], axis=1, inplace=True)

# %%
df_p.isnull().sum()
# Out:
# patient_nbr                  0
# race                         0
# gender                       0
# age                          0
# admission_type_id            0
# discharge_disposition_id     0
# admission_source_id          0
# time_in_hospital             0
# num_lab_procedures           0
# num_procedures               0
# num_medications              0
# number_outpatient_log1p      0
# number_emergency_log1p       0
# number_inpatient_log1p       0
# number_diagnoses             0
# max_glu_serum                0
# A1Cresult                    0
# metformin                    0
# repaglinide                  0
# nateglinide                  0
# chlorpropamide               0
# glimepiride                  0
# acetohexamide                0
# glipizide                    0
# glyburide                    0
# tolbutamide                  0
# pioglitazone                 0
# rosiglitazone                0
# acarbose                     0
# miglitol                     0
# troglitazone                 0
# tolazamide                   0
# insulin                      0
# glyburide-metformin          0
# glipizide-metformin          0
# glimepiride-pioglitazone     0
# metformin-rosiglitazone      0
# metformin-pioglitazone       0
# change                       0
# diabetesMed                  0
# readmitted                   0
# service_utilization_log1p    0
# level1_diag1                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90363 entries, 2 to 101765
# Data columns (total 52 columns):
# encounter_id                 90363 non-null int64
# patient_nbr                  90363 non-null int64
# race                         90363 non-null object
# gender                       90363 non-null object
# age                          90363 non-null float64
# admission_type_id            90363 non-null object
# discharge_disposition_id     90363 non-null object
# admission_source_id          90363 non-null object
# time_in_hospital             90363 non-null float64
# num_lab_procedures           90363 non-null float64
# num_procedures               90363 non-null float64
# num_medications              90363 non-null float64
# diag_1                       90363 non-null object
# diag_2                       90363 non-null object
# diag_3                       90363 non-null object
# number_diagnoses             90363 non-null float64
# max_glu_serum                90363 non-null object
# A1Cresult                    90363 non-null int64
# metformin                    90363 non-null int64
# repaglinide                  90363 non-null int64
# nateglinide                  90363 non-null int64
# chlorpropamide               90363 non-null int64
# glimepiride                  90363 non-null int64
# acetohexamide                90363 non-null int64
# glipizide                    90363 non-null int64
# glyburide                    90363 non-null int64
# tolbutamide                  90363 non-null int64
# pioglitazone                 90363 non-null int64
# rosiglitazone                90363 non-null int64
# acarbose                     90363 non-null int64
# miglitol                     90363 non-null int64
# troglitazone                 90363 non-null int64
# tolazamide                   90363 non-null int64
# insulin                      90363 non-null int64
# glyburide-metformin          90363 non-null int64
# glipizide-metformin          90363 non-null int64
# glimepiride-pioglitazone     90363 non-null int64
# metformin-rosiglitazone      90363 non-null int64
# metformin-pioglitazone       90363 non-null int64
# change                       90363 non-null int64
# diabetesMed                  90363 non-null int64
# readmitted                   90363 non-null int64
# level1_diag1                 90363 non-null object
# level2_diag1                 90363 non-null object
# level1_diag2                 90363 non-null object
# level2_diag2                 90363 non-null object
# level1_diag3                 90363 non-null object
# level2_diag3                 90363 non-null object
# number_inpatient_log1p       90363 non-null float64
# service_utilization_log1p    90363 non-null float64
# number_outpatient_log1p      90363 non-null float64
# number_emergency_log1p       90363 non-null float64
# dtypes: float64(10), int64(27), object(15)
# memory usage: 36.5+ MB

# %%
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58830 entries, 1 to 70441
# Data columns (total 43 columns):
# patient_nbr                  58830 non-null int64
# race                         58830 non-null object
# gender                       58830 non-null int64
# age                          58830 non-null float64
# admission_type_id            58830 non-null int64
# discharge_disposition_id     58830 non-null int64
# admission_source_id          58830 non-null int64
# time_in_hospital             58830 non-null float64
# num_lab_procedures           58830 non-null float64
# num_procedures               58830 non-null float64
# num_medications              58830 non-null float64
# number_outpatient_log1p      58830 non-null float64
# number_emergency_log1p       58830 non-null float64
# number_inpatient_log1p       58830 non-null float64
# number_diagnoses             58830 non-null float64
# max_glu_serum                58830 non-null int64
# A1Cresult                    58830 non-null int64
# metformin                    58830 non-null float64
# repaglinide                  58830 non-null float64
# nateglinide                  58830 non-null float64
# chlorpropamide               58830 non-null float64
# glimepiride                  58830 non-null float64
# acetohexamide                58830 non-null int64
# glipizide                    58830 non-null float64
# glyburide                    58830 non-null float64
# tolbutamide                  58830 non-null int64
# pioglitazone                 58830 non-null float64
# rosiglitazone                58830 non-null float64
# acarbose                     58830 non-null float64
# miglitol                     58830 non-null float64
# troglitazone                 58830 non-null int64
# tolazamide                   58830 non-null float64
# insulin                      58830 non-null float64
# glyburide-metformin          58830 non-null float64
# glipizide-metformin          58830 non-null int64
# glimepiride-pioglitazone     58830 non-null int64
# metformin-rosiglitazone      58830 non-null int64
# metformin-pioglitazone       58830 non-null int64
# change                       58830 non-null int64
# diabetesMed                  58830 non-null float64
# readmitted                   58830 non-null float64
# service_utilization_log1p    58830 non-null float64
# level1_diag1                 58830 non-null float64
# dtypes: float64(27), int64(15), object(1)
# memory usage: 19.7+ MB

# %%
import seaborn as sns
from matplotlib.colors import ListedColormap
# my_cmap = ListedColormap(sns.color_palette("RdYlGn", n_colors=15).as_hex())
# my_cmap = ListedColormap(sns.diverging_palette(150, 250, sep=120, n=28, center="light").as_hex())

my_cmap = ListedColormap(sns.light_palette((250, 100, 50), input="husl", n_colors=50).as_hex())
# drop some columns due to their means is round to 0
table = df.drop(['acetohexamide','tolbutamide', 'troglitazone', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone','patient_nbr', 'encounter_id', 'service_utilization_log1p'], axis = 1).corr(method='pearson')
table.style.background_gradient(cmap=my_cmap, axis = 0)
# Out:
# <style  type="text/css" >
#     #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col0 {
#             background-color:  #007ad1;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col1 {
#             background-color:  #cae5f9;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col2 {
#             background-color:  #ddf0fd;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col3 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col4 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col5 {
#             background-color:  #bbdef6;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col6 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col7 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col8 {
#             background-color:  #d8edfc;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col9 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col10 {
#             background-color:  #d4ebfb;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row0_col11 {
#             background-color:  #d8edfc;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col0 {
#             background-color:  #c5e3f8;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col1 {
#             background-color:  #007ad1;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col2 {
#             background-color:  #9bccf0;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col3 {
#             background-color:  #b7dbf6;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col4 {
#             background-color:  #83c0eb;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col5 {
#             background-color:  #bbdef6;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col6 {
#             background-color:  #cae5f9;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col7 {
#             background-color:  #d8edfc;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col8 {
#             background-color:  #d8edfc;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col9 {
#             background-color:  #e1f2fe;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col10 {
#             background-color:  #c5e3f8;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row1_col11 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col0 {
#             background-color:  #d8edfc;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col1 {
#             background-color:  #9bccf0;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col2 {
#             background-color:  #007ad1;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col3 {
#             background-color:  #d4ebfb;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col4 {
#             background-color:  #b2d9f5;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col5 {
#             background-color:  #cae5f9;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col6 {
#             background-color:  #d4ebfb;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col7 {
#             background-color:  #ddf0fd;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col8 {
#             background-color:  #d8edfc;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col9 {
#             background-color:  #e1f2fe;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col10 {
#             background-color:  #cee8fa;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row2_col11 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col0 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col1 {
#             background-color:  #c1e1f8;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col2 {
#             background-color:  #ddf0fd;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col3 {
#             background-color:  #007ad1;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col4 {
#             background-color:  #a4d1f2;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col5 {
#             background-color:  #e1f2fe;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col6 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col7 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col8 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col9 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col10 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row3_col11 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col0 {
#             background-color:  #d8edfc;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col1 {
#             background-color:  #7fbdea;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col2 {
#             background-color:  #a9d4f3;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col3 {
#             background-color:  #91c7ee;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col4 {
#             background-color:  #007ad1;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col5 {
#             background-color:  #b2d9f5;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col6 {
#             background-color:  #a9d4f3;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col7 {
#             background-color:  #b7dbf6;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col8 {
#             background-color:  #d4ebfb;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col9 {
#             background-color:  #d8edfc;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col10 {
#             background-color:  #c5e3f8;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row4_col11 {
#             background-color:  #d4ebfb;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col0 {
#             background-color:  #aed7f4;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col1 {
#             background-color:  #b2d9f5;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col2 {
#             background-color:  #c1e1f8;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col3 {
#             background-color:  #cee8fa;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col4 {
#             background-color:  #b2d9f5;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col5 {
#             background-color:  #007ad1;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col6 {
#             background-color:  #d4ebfb;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col7 {
#             background-color:  #ddf0fd;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col8 {
#             background-color:  #cae5f9;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col9 {
#             background-color:  #d4ebfb;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col10 {
#             background-color:  #bbdef6;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row5_col11 {
#             background-color:  #cee8fa;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row6_col0 {
#             background-color:  #e6f4ff;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row6_col1 {
#             background-color:  #cee8fa;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row6_col2 {
#             background-color:  #d4ebfb;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row6_col3 {
#             background-color:  #ddf0fd;
#         }    #T_e63c60f6_d4ef_11e7_9d60_720003188670row6_col4 {

# %%
table2 = df_p.drop(['service_utilization_log1p', 'patient_nbr'], axis = 1).corr(method='pearson')
table2.style.background_gradient(cmap=my_cmap, axis = 0)
# Out:
# <style  type="text/css" >
#     #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col0 {
#             background-color:  #007ad1;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col1 {
#             background-color:  #d8edfc;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col2 {
#             background-color:  #cee8fa;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col3 {
#             background-color:  #e1f2fe;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col4 {
#             background-color:  #cae5f9;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col5 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col6 {
#             background-color:  #cee8fa;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col7 {
#             background-color:  #c1e1f8;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col8 {
#             background-color:  #ddf0fd;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col9 {
#             background-color:  #e1f2fe;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col10 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col11 {
#             background-color:  #ddf0fd;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col12 {
#             background-color:  #cee8fa;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col13 {
#             background-color:  #ddf0fd;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col14 {
#             background-color:  #ddf0fd;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col15 {
#             background-color:  #e1f2fe;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col16 {
#             background-color:  #ddf0fd;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col17 {
#             background-color:  #cee8fa;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row0_col18 {
#             background-color:  #cae5f9;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col0 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col1 {
#             background-color:  #007ad1;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col2 {
#             background-color:  #d4ebfb;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col3 {
#             background-color:  #c5e3f8;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col4 {
#             background-color:  #c5e3f8;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col5 {
#             background-color:  #c1e1f8;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col6 {
#             background-color:  #c5e3f8;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col7 {
#             background-color:  #d4ebfb;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col8 {
#             background-color:  #cae5f9;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col9 {
#             background-color:  #d8edfc;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col10 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col11 {
#             background-color:  #d8edfc;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col12 {
#             background-color:  #96caef;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col13 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col14 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col15 {
#             background-color:  #d4ebfb;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col16 {
#             background-color:  #d8edfc;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col17 {
#             background-color:  #c5e3f8;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row1_col18 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col0 {
#             background-color:  #ddf0fd;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col1 {
#             background-color:  #cee8fa;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col2 {
#             background-color:  #007ad1;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col3 {
#             background-color:  #cae5f9;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col4 {
#             background-color:  #b2d9f5;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col5 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col6 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col7 {
#             background-color:  #aed7f4;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col8 {
#             background-color:  #c5e3f8;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col9 {
#             background-color:  #d4ebfb;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col10 {
#             background-color:  #e1f2fe;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col11 {
#             background-color:  #d4ebfb;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col12 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col13 {
#             background-color:  #e1f2fe;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col14 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col15 {
#             background-color:  #d8edfc;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col16 {
#             background-color:  #c5e3f8;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col17 {
#             background-color:  #7fbdea;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row2_col18 {
#             background-color:  #ddf0fd;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col0 {
#             background-color:  #e1f2fe;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col1 {
#             background-color:  #b7dbf6;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col2 {
#             background-color:  #bbdef6;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col3 {
#             background-color:  #007ad1;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col4 {
#             background-color:  #cee8fa;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col5 {
#             background-color:  #bbdef6;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col6 {
#             background-color:  #cae5f9;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col7 {
#             background-color:  #cae5f9;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col8 {
#             background-color:  #c1e1f8;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col9 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col10 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col11 {
#             background-color:  #e1f2fe;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col12 {
#             background-color:  #c5e3f8;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col13 {
#             background-color:  #e1f2fe;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col14 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col15 {
#             background-color:  #e6f4ff;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col16 {
#             background-color:  #cee8fa;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col17 {
#             background-color:  #cae5f9;
#         }    #T_e656be1a_d4ef_11e7_90fe_720003188670row3_col18 {
#             background-color:  #d4ebfb;
#         }    #T_e656be1a_d4ef_11e7_90fe_720

# %%
df_pd = pd.get_dummies(df_p, columns=['race', 'gender', 'admission_type_id', 'discharge_disposition_id',
                                      'admission_source_id', 'max_glu_serum', 'A1Cresult', ])

# %%
non_cols = ['race', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'max_glu_serum', 'A1Cresult', ]

# %%
numerics = list(set(list(df._get_numeric_data().columns))- {'readmitted', 'change'})
numerics
# Out:
# ['insulin',
#  'metformin',
#  'num_medications',
#  'repaglinide',
#  'service_utilization_log1p',
#  'number_outpatient_log1p',
#  'num_lab_procedures',
#  'nateglinide',
#  'glyburide-metformin',
#  'pioglitazone',
#  'num_procedures',
#  'miglitol',
#  'glimepiride',
#  'metformin-rosiglitazone',
#  'glipizide',
#  'glipizide-metformin',
#  'number_emergency_log1p',
#  'diabetesMed',
#  'chlorpropamide',
#  'rosiglitazone',
#  'A1Cresult',
#  'age',
#  'acetohexamide',
#  'number_diagnoses',
#  'metformin-pioglitazone',
#  'tolazamide',
#  'glyburide',
#  'encounter_id',
#  'glimepiride-pioglitazone',
#  'time_in_hospital',
#  'patient_nbr',
#  'number_inpatient_log1p',
#  'tolbutamide',
#  'acarbose',
#  'troglitazone']

# %%
new_non_cols = []
for i in non_cols:
    for j in df_pd.columns:
        if i in j:
            new_non_cols.append(j)

# %%
new_non_cols
# Out:
# ['race_?',
#  'race_AfricanAmerican',
#  'race_Asian',
#  'race_Caucasian',
#  'race_Hispanic',
#  'race_Other',
#  'gender_0',
#  'gender_1',
#  'admission_type_id_1',
#  'admission_type_id_2',
#  'admission_type_id_3',
#  'admission_type_id_4',
#  'admission_type_id_5',
#  'admission_type_id_6',
#  'admission_type_id_7',
#  'admission_type_id_8',
#  'discharge_disposition_id_1',
#  'discharge_disposition_id_2',
#  'discharge_disposition_id_3',
#  'discharge_disposition_id_4',
#  'discharge_disposition_id_5',
#  'discharge_disposition_id_6',
#  'discharge_disposition_id_7',
#  'discharge_disposition_id_8',
#  'discharge_disposition_id_9',
#  'discharge_disposition_id_10',
#  'discharge_disposition_id_12',
#  'discharge_disposition_id_13',
#  'discharge_disposition_id_14',
#  'discharge_disposition_id_15',
#  'discharge_disposition_id_16',
#  'discharge_disposition_id_17',
#  'discharge_disposition_id_18',
#  'discharge_disposition_id_19',
#  'discharge_disposition_id_20',
#  'discharge_disposition_id_22',
#  'discharge_disposition_id_23',
#  'discharge_disposition_id_24',
#  'discharge_disposition_id_25',
#  'discharge_disposition_id_27',
#  'discharge_disposition_id_28',
#  'admission_source_id_1',
#  'admission_source_id_2',
#  'admission_source_id_3',
#  'admission_source_id_4',
#  'admission_source_id_5',
#  'admission_source_id_6',
#  'admission_source_id_7',
#  'admission_source_id_8',
#  'admission_source_id_9',
#  'admission_source_id_10',
#  'admission_source_id_11',
#  'admission_source_id_13',
#  'admission_source_id_14',
#  'admission_source_id_17',
#  'admission_source_id_20',
#  'admission_source_id_22',
#  'admission_source_id_25',
#  'max_glu_serum_-99',
#  'max_glu_serum_0',
#  'max_glu_serum_1',
#  'A1Cresult_-99',
#  'A1Cresult_0',
#  'A1Cresult_1']

# %%
train_input = df_pd.drop(['readmitted', 'change'], axis= 1)
train_output = df_pd['readmitted']

# %%
train_input.columns
# Out:
# Index(['patient_nbr', 'age', 'time_in_hospital', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient_log1p',
#        'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'diabetesMed', 'service_utilization_log1p',
#        'level1_diag1', 'race_?', 'race_AfricanAmerican', 'race_Asian',
#        'race_Caucasian', 'race_Hispanic', 'race_Other', 'gender_0', 'gender_1',
#        'admission_type_id_1', 'admission_type_id_2', 'admission_type_id_3',
#        'admission_type_id_4', 'admission_type_id_5', 'admission_type_id_6',
#        'admission_type_id_7', 'admission_type_id_8',
#        'discharge_disposition_id_1', 'discharge_disposition_id_2',
#        'discharge_disposition_id_3', 'discharge_disposition_id_4',
#        'discharge_disposition_id_5', 'discharge_disposition_id_6',
#        'discharge_disposition_id_7', 'discharge_disposition_id_8',
#        'discharge_disposition_id_9', 'discharge_disposition_id_10',
#        'discharge_disposition_id_12', 'discharge_disposition_id_13',
#        'discharge_disposition_id_14', 'discharge_disposition_id_15',
#        'discharge_disposition_id_16', 'discharge_disposition_id_17',
#        'discharge_disposition_id_18', 'discharge_disposition_id_19',
#        'discharge_disposition_id_20', 'discharge_disposition_id_22',
#        'discharge_disposition_id_23', 'discharge_disposition_id_24',
#        'discharge_disposition_id_25', 'discharge_disposition_id_27',
#        'discharge_disposition_id_28', 'admission_source_id_1',
#        'admission_source_id_2', 'admission_source_id_3',
#        'admission_source_id_4', 'admission_source_id_5',
#        'admission_source_id_6', 'admission_source_id_7',
#        'admission_source_id_8', 'admission_source_id_9',
#        'admission_source_id_10', 'admission_source_id_11',
#        'admission_source_id_13', 'admission_source_id_14',
#        'admission_source_id_17', 'admission_source_id_20',
#        'admission_source_id_22', 'admission_source_id_25', 'max_glu_serum_-99',
#        'max_glu_serum_0', 'max_glu_serum_1', 'A1Cresult_-99', 'A1Cresult_0',
#        'A1Cresult_1'],
#       dtype='object')

# %%
full_feature_list = ['age', 'time_in_hospital', 'num_lab_procedures',
       'num_procedures', 'num_medications', 'number_outpatient_log1p',
       'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses',
       'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
       'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
       'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
       'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin',
       'glimepiride-pioglitazone', 'metformin-rosiglitazone',
       'metformin-pioglitazone', 'diabetesMed', 'service_utilization_log1p',
       'level1_diag1', 'race_?', 'race_AfricanAmerican', 'race_Asian',
       'race_Caucasian', 'race_Hispanic', 'race_Other', 'gender_0', 'gender_1',
       'admission_type_id_1', 'admission_type_id_2', 'admission_type_id_3',
       'admission_type_id_4', 'admission_type_id_5', 'admission_type_id_6',
       'admission_type_id_7', 'admission_type_id_8',
       'discharge_disposition_id_1', 'discharge_disposition_id_2',
       'discharge_disposition_id_3', 'discharge_disposition_id_4',
       'discharge_disposition_id_5', 'discharge_disposition_id_6',
       'discharge_disposition_id_7', 'discharge_disposition_id_8',
       'discharge_disposition_id_9', 'discharge_disposition_id_10',
       'discharge_disposition_id_12', 'discharge_disposition_id_13',
       'discharge_disposition_id_14', 'discharge_disposition_id_15',
       'discharge_disposition_id_16', 'discharge_disposition_id_17',
       'discharge_disposition_id_18', 'discharge_disposition_id_19',
       'discharge_disposition_id_20', 'discharge_disposition_id_22',
       'discharge_disposition_id_23', 'discharge_disposition_id_24',
       'discharge_disposition_id_25', 'discharge_disposition_id_27',
       'discharge_disposition_id_28', 'admission_source_id_1',
       'admission_source_id_2', 'admission_source_id_3',
       'admission_source_id_4', 'admission_source_id_5',
       'admission_source_id_6', 'admission_source_id_7',
       'admission_source_id_8', 'admission_source_id_9',
       'admission_source_id_10', 'admission_source_id_11',
       'admission_source_id_13', 'admission_source_id_14',
       'admission_source_id_17', 'admission_source_id_20',
       'admission_source_id_22', 'admission_source_id_25', 'max_glu_serum_-99',
       'max_glu_serum_0', 'max_glu_serum_1', 'A1Cresult_-99', 'A1Cresult_0',
       'A1Cresult_1']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_dev, Y_train, Y_dev = train_test_split(train_input[full_feature_list], train_output, test_size=0.20, random_state=0)
Y_dev = Y_dev.astype(int)
Y_train = Y_train.astype(int)
logreg = LogisticRegression(fit_intercept=True, penalty='l1')
print("Cross Validation Score: {:.2%}".format(np.mean(cross_val_score(logreg, X_train, Y_train, cv=25))))
logreg.fit(X_train, Y_train)
print("Dev Set score: {:.2%}".format(logreg.score(X_dev, Y_dev)))
# Out:
# Cross Validation Score: 72.68%
# Dev Set score: 72.78%

# %%
Y_dev_predict = logreg.predict(X_dev)

# %%
pd.crosstab(pd.Series(Y_dev, name = 'Actual'), pd.Series(Y_dev_predict, name = 'Predict'), margins = True)
# Out:
# Predict   0.0  1.0  2.0   All
# Actual
# 0.0      1483   17   46  1546
# 1.0       167    3    5   175
# 2.0       194    1    3   198
# All      1844   21   54  1919

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
print("Accuracy is {0:.2f}".format(accuracy_score(Y_dev, Y_dev_predict)))
#print("Precision is {0:.2f}".format(precision_score(Y_dev, Y_dev_predict)))
#print("Recall is {0:.2f}".format(recall_score(Y_dev, Y_dev_predict)))
# Out:
# Accuracy is 0.73

# %%
[print(fname, coeffs) for fname, coeffs in zip(X_train.columns, np.round(logreg.coef_[0],3))];
# Out:
# age -0.005
# time_in_hospital -0.008
# num_lab_procedures -0.003
# num_procedures 0.005
# num_medications 0.003
# number_outpatient_log1p 0.17
# number_emergency_log1p -0.0
# number_inpatient_log1p -1.297
# number_diagnoses -0.082
# metformin 0.034
# repaglinide -0.274
# nateglinide 0.579
# chlorpropamide 0.0
# glimepiride 0.08
# acetohexamide 0.0
# glipizide -0.092
# glyburide 0.014
# tolbutamide 0.0
# pioglitazone -0.448
# rosiglitazone 0.597
# acarbose -0.549
# miglitol 0.0
# troglitazone 0.0
# tolazamide 0.0
# insulin 0.035
# glyburide-metformin 0.0
# glipizide-metformin 0.0
# glimepiride-pioglitazone 0.0
# metformin-rosiglitazone 0.0
# metformin-pioglitazone 0.0
# diabetesMed -0.257
# service_utilization_log1p -0.648
# level1_diag1 0.029
# race_? 0.0
# race_AfricanAmerican 0.0
# race_Asian 0.221
# race_Caucasian -0.118
# race_Hispanic 0.197
# race_Other 0.104
# gender_0 0.67
# gender_1 0.693
# admission_type_id_1 0.069
# admission_type_id_2 0.0
# admission_type_id_3 0.16
# admission_type_id_4 0.0
# admission_type_id_5 0.37
# admission_type_id_6 -0.856
# admission_type_id_7 0.963
# admission_type_id_8 0.177
# discharge_disposition_id_1 -0.159
# discharge_disposition_id_2 -0.095
# discharge_disposition_id_3 0.0
# discharge_disposition_id_4 0.0
# discharge_disposition_id_5 -0.413
# discharge_disposition_id_6 -0.232
# discharge_disposition_id_7 0.254
# discharge_disposition_id_8 0.128
# discharge_disposition_id_9 0.0
# discharge_disposition_id_10 0.0
# discharge_disposition_id_12 0.0
# discharge_disposition_id_13 1.831
# discharge_disposition_id_14 2.249
# discharge_disposition_id_15 -0.643
# discharge_disposition_id_16 0.0
# discharge_disposition_id_17 0.0
# discharge_disposition_id_18 0.416
# discharge_disposition_id_19 0.0
# discharge_disposition_id_20 0.0
# discharge_disposition_id_22 -0.342
# discharge_disposition_id_23 0.486
# discharge_disposition_id_24 1.385
# discharge_disposition_id_25 0.793
# discharge_disposition_id_27 0.0
# discharge_disposition_id_28 -0.264
# admission_source_id_1 -0.214
# admission_source_id_2 -0.098
# admission_source_id_3 -0.241
# admission_source_id_4 0.16
# admission_source_id_5 0.106
# admission_source_id_6 0.372
# admission_source_id_7 -0.265
# admission_source_id_8 0.031
# admission_source_id_9 1.911
# admission_source_id_10 0.0
# admission_source_id_11 0.0
# admission_source_id_13 0.0
# admission_source_id_14 0.0
# admission_source_id_17 0.051
# admission_source_id_20 -1.357
# admission_source_id_22 0.646
# admission_source_id_25 0.0
# max_glu_serum_-99 1.119
# max_glu_serum_0 1.259
# max_glu_serum_1 1.049
# A1Cresult_-99 0.318
# A1Cresult_0 0.294
# A1Cresult_1 0.236

# %%
df_p.readmitted.mean()
# Out:
# 0.4771979201696176
